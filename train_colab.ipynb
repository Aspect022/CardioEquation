# %% [markdown]
# # CardioEquation: Personalized ECG Digital Twin - Colab Training
#
# This notebook is designed to train the **Forecasting (Phase 4)** model on Google Colab using a T4 GPU.
#
# **Prerequisites:**
# 1. Upload the entire `CardioEquation` project folder to your Google Drive.
# 2. Ensure `data/mitbih_forecasting.npz` exists.
# 3. Ensure Phase 2 weights (`models/feature_extractor_epoch_02.weights.h5` and `models/diffusion_unet_epoch_02.weights.h5`) are present in the `models` folder.
#
# ---

# %% [markdown]
# ### 1. Mount Google Drive
# This allows access to your uploaded project files.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### 2. Navigate to Project Directory
# **IMPORTANT:** Change the path below to match where you uploaded the `CardioEquation` folder in your Drive.

# %%
import os

# CHANGE THIS PATH if your folder is named differently or in a subfolder
PROJECT_PATH = '/content/drive/MyDrive/CardioEquation'

try:
    os.chdir(PROJECT_PATH)
    print(f"✅ Changed directory to: {os.getcwd()}")
except FileNotFoundError:
    print(f"❌ Path not found: {PROJECT_PATH}")
    print("Please check your Google Drive structure.")

# %% [markdown]
# ### 3. Install Dependencies
# Installing required libraries from `requirements.txt`.

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ### 4. Verify GPU Availability
# Ensure we are connected to a T4 GPU.

# %%
import tensorflow as tf
print(f"TensorFlow Version: {tf.__version__}")

gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print(f"✅ GPU Detected: {gpus}")
    # !nvidia-smi
else:
    print("⚠️ No GPU detected. Please go to Runtime > Change runtime type > T4 GPU.")

# %% [markdown]
# ### 5. Run Training (Phase 4)
# This starts the training process. The model will save checkpoints to the `models/` folder in your Drive automatically.

# %%
# Set python path to include current directory so imports work correctly
import sys
sys.path.append(os.getcwd())

# Run the forecasting training script
# !python src/training/train_forecasting.py
